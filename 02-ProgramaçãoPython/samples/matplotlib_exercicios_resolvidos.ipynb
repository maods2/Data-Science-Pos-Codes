# %% [markdown]
# #Praticando a criação de visualizações de dados com a biblioteca Matplotlib

# %% [markdown]
# Referêcia: [PYnative](https://pynative.com/python-matplotlib-exercise/)

# %% [markdown]
# ###Importe as bibliotecas necessárias para manipulação e visualização de dados

# %%
from google.colab import files 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 01. Defina um estilo padrão para os gráficos que você vai gerar nesse exercício

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### 02. Defina um tamanho padrão para os seus gráficos, bem como o tamanho da fonte dos títulos das figuras, dos gráficos, dos eixos, bem como o tamanho da fonte dos marcadores dos eixos e das legendas.

# %%
mpl.rcParams["figure.figsize"] = [10, 7]
mpl.rcParams['figure.titlesize'] = 18
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 'large'

# %% [markdown]
# ### 03. Antes de começar a serem visualizados, os dados precisam ser carregados. Importe os dados do dataset 'company_sales_data.csv' disponibilizado junto com esta atividade.

# %%
files.upload()
sales = pd.read_csv('sales.csv')
sales
# Out:
#      <input type="file" id="files-69ffda27-f0b4-499d-b973-3f0fd480219e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69ffda27-f0b4-499d-b973-3f0fd480219e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales.csv to sales.csv
#     month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0              1       2500      1500  ...         1500        21100        211000
# 1              2       2630      1200  ...         1200        18330        183300
# 2              3       2140      1340  ...         1340        22470        224700
# 3              4       3400      1130  ...         1130        22270        222700
# 4              5       3600      1740  ...         1740        20960        209600
# 5              6       2760      1555  ...         1555        20140        201400
# 6              7       2980      1120  ...         1120        29550        295500
# 7              8       3700      1400  ...         1400        36140        361400
# 8              9       3540      1780  ...         1780        23400        234000
# 9             10       1990      1890  ...         1890        26670        266700
# 10            11       2340      2100  ...         2100        41280        412800
# 11            12       2900      1760  ...         1760        30020        300200
#
# [12 rows x 9 columns]

# %% [markdown]
# ### 04. Leia o lucro total (total_profit) de todos os meses e mostre-o usando um gráfico de linha.

# %% [markdown]
# O gráfico deve se parecer com esse:
#
# ![image.png](data:image/png;base64,...)

# %%
plt.plot('month_number', 'total_profit', data=sales)
plt.xlabel('Mês')
plt.ylabel('Lucro ($)')
plt.xticks(sales.month_number)
plt.title('Lucro obtido por mês')
plt.show()

# %% [markdown]
# ### 05. Obtenha o lucro total de todos os meses e mostre o gráfico de linha com as seguintes propriedades de estilo
#
# O gráfico de linha gerado deve incluir as seguintes propriedades de estilo: -
#
# - Título do gráfico = Lucro obtido por mês;
# - Nome do rótulo X = Mês;
# - Nome do rótulo Y = Quantidade de unidades vendidas;
# - Estilo de linha tracejado e cor de linha deve ser azul;
# - Mostre a legenda no local inferior direito;
# - Adicione um marcador de círculo vermelho com a borda branca;
# - A largura da linha deve ser 3.

# %% [markdown]
# O gráfico deve ser semelhante a este:
#
# ![image.png](data:image/png;base64,...)

# %%
plt.plot('month_number', 'total_profit', data=sales, 
         label = 'Profit data of last year', 
         color='b', marker='o', markerfacecolor='r', 
         markeredgecolor='w', linestyle='--', linewidth=3)
plt.xlabel('Mês')
plt.ylabel('Lucro ($)')
plt.xticks(sales.month_number)
plt.title('Lucro obtido por mês')
plt.show()

# %% [markdown]
# ### 06. Exiba o número de unidades vendidas por mês para cada produto usando um gráfico multilinha.

# %% [markdown]
# O gráfico deve ser semelhante a esse:
#
# ![image.png](data:image/png;base64,...)

# %%
sales.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
plt.plot('month_number', 'facecream', data=sales, label = 'Creme facial', marker='o', linewidth=3)
plt.plot('month_number', 'facewash', data=sales, label = 'Sabonete de rosto',  marker='o', linewidth=3)
plt.plot('month_number', 'toothpaste', data=sales, label = 'Pasta de dente', marker='o', linewidth=3)
plt.plot('month_number', 'bathingsoap', data=sales, label = 'Sabonete de banho', marker='o', linewidth=3)
plt.plot('month_number', 'shampoo', data=sales, label = 'Shampoo', marker='o', linewidth=3)
plt.plot('month_number', 'moisturizer', data=sales, label = 'Hidratante', marker='o', linewidth=3)

plt.xlabel('Mês')
plt.ylabel('Unidades vendidas')
plt.xticks(sales.month_number)
plt.title('Quantidade de unidades vendidas por mês')
plt.legend()
plt.show()

# %% [markdown]
# ### 7. Exiba em um gráfico de dispersão que exiba a quantidade de unidades de pasta de dente vendidas por mês.
#
# Além disso, mude a grade de linhas para o estilo tracejado.

# %% [markdown]
# O gráfico de dispersão deve ser semelhante a este:
#
# ![image.png](data:image/png;base64,...)

# %%
plt.scatter('month_number', 'toothpaste', data=sales)

plt.xlabel('Mês')
plt.ylabel('Unidades vendidas')
plt.xticks(sales.month_number)
plt.title('Unidades de pasta de dente vendidas por mês')
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %% [markdown]
# ### 08. Exiba o lucro total obtido por mês em um histograma com 6 bins.
#
# Rotacione em 45° os labels dos marcadores do eixo x (xticks) para evitar sobreposições.

# %% [markdown]
# O histograma deve ser semelhante a este:
#
# ![image.png](data:image/png;base64,...)

# %%
plt.hist(sales.total_profit, bins=6, alpha=0.5)
plt.xticks(rotation=45);

# %% [markdown]
# ### 09. Calcule o total de vendas de cada produto por semestre e apresente-os usando dois gráficos de pizza. Cada gráfico deve trazer o rótulo e o valor percentual de cada fatia.

# %% [markdown]
# O gráfico deve ser semelhante a esse:
#
# ![image.png](data:image/png;base64,...)

# %%
labels = ['Creme facial', 'Sabonete de rosto', 'Pasta de dente', 'Sabonete', 'Shampoo', 'Hidratante']
sales_semestre_1 = [sales['facecream'].iloc[:6].sum(), sales['facewash'].iloc[:6].sum(), 
                    sales['toothpaste'].iloc[:6].sum(), sales['bathingsoap'].iloc[:6].sum(), 
                    sales['shampoo'].iloc[:6].sum(), sales['moisturizer'].iloc[:6].sum()]

sales_semestre_2 = [sales['facecream'].iloc[6:].sum(), sales['facewash'].iloc[6:].sum(), 
                    sales['toothpaste'].iloc[6:].sum(), sales['bathingsoap'].iloc[6:].sum(), 
                    sales['shampoo'].iloc[6:].sum(), sales['moisturizer'].iloc[6:].sum()]

fig, (ax1, ax2) = plt.subplots(1,2)
ax1.pie(sales_semestre_1, labels=labels, autopct='%1.1f%%')
ax2.pie(sales_semestre_2, labels=labels, autopct='%1.1f%%')
fig.subplots_adjust(hspace=0.4, wspace=0.4)
fig.set_size_inches(15,10)
ax1.set_title('Vendas no 1º semestre')
ax2.set_title('Vendas no 2º semestre')
plt.show()

# %% [markdown]
# #### Existe algum diferença destacável na proporção de vendas entre os semestres? Responda com um print()

# %% [markdown]
# ### 10. Exiba o total de vendas de cada produto ao longo dos meses em um gráfico de área. Defina um grau de transparência ao gráfico para deixar a visualização mais agradável.

# %% [markdown]
# O gráfico deve ser semelhante a esse:
#
# ![image.png](data:image/png;base64,...)

# %%
labels = ['Creme facial', 'Sabonete de rosto', 'Pasta de dente', 'Sabonete', 'Shampoo', 'Hidratante']
plt.stackplot(sales.month_number, sales.facecream, sales.facewash, sales.toothpaste, 
              sales.bathingsoap, sales.shampoo, sales.moisturizer, labels=labels, alpha=0.7)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 11. Compare o volume de vendas de hidratante e creme facial com um gráfico de barras.
#
# O gráfico de barras deve exibir o número de unidades vendidas por mês para cada produto. Adicione uma barra separada para cada produto no mesmo gráfico.
#
# Neste mesmo gráfico, apresente o total de produtos vendidos em cada mês. Como a escala de quantidade de produtos é diferente da escala de lucro, crie um eixo gêmeo (pesquise por twin axes).

# %% [markdown]
# O gráico deve ser semelhante a esse:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax1 = plt.subplots()

ax1.bar([a-0.4 for a in sales.month_number], sales.moisturizer, width= 0.4, label = 'Vendas de Creme facial', align='edge')
ax1.bar([a for a in sales.month_number], sales.facecream, width= 0.4, label = 'Vendas de Hidratante', align='edge')
ax1.grid(False)
ax_twin = ax1.twinx()


ax_twin.plot(sales.month_number, sales.total_profit, 
             marker='o', color='g', markersize=10, linewidth=4,
             markerfacecolor='w')

ax1.set_xlabel('Mês')
ax1.set_xticks(sales.month_number)
ax1.set_ylabel('Unidades vendidas')
ax1.legend(loc='upper left')
ax1.set_title('Vendas de hidratante e creme facial');

# %% [markdown]
# ### 12. Crie uma grade de subplots e, para cada painel, exiba um gráfico de dispersão relacionando os dados de vendas de cada produto e o total de lucro obtido no mês. Na última linha da grade deve ser apresentado um único painel com um gráfico de caixas exibindo a distribuição de vendas de cada produto.

# %%
produtos = {'facecream':'Creme facial', 'facewash':'Sabonete de rosto', 
          'toothpaste':'Pasta de dente', 'bathingsoap':'Sabonete', 
          'shampoo':'Shampoo', 'moisturizer':'Hidratante'}

# %%
colunas = list(produtos.keys())

# %%
a = sales.loc[:, colunas]
a
# Out:
#     facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# 0        2500      1500        5200         9200     1200         1500
# 1        2630      1200        5100         6100     2100         1200
# 2        2140      1340        4550         9550     3550         1340
# 3        3400      1130        5870         8870     1870         1130
# 4        3600      1740        4560         7760     1560         1740
# 5        2760      1555        4890         7490     1890         1555
# 6        2980      1120        4780         8980     1780         1120
# 7        3700      1400        5860         9960     2860         1400
# 8        3540      1780        6100         8100     2100         1780
# 9        1990      1890        8300        10300     2300         1890
# 10       2340      2100        7300        13300     2400         2100
# 11       2900      1760        7400        14400     1800         1760

# %%
fig = plt.figure(figsize=(15, 20))
grid = plt.GridSpec(4, 3, wspace=0.4, hspace=0.3)

for i in range(2):
    for j in range(3):
      ax = fig.add_subplot(grid[i, j])
      ax.scatter('total_profit', colunas[(i+j)], data=sales)
      ax.set_xlabel('Lucro total obtido')
      ax.set_ylabel('Vendas de ' + produtos[colunas[(i+j)]])


ax = fig.add_subplot(grid[2:, :])
sales.loc[:, colunas].boxplot(ax=ax)
